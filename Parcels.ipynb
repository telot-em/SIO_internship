# %%
load_path2='/data/SO12/runs/RUN_BLING_Dec2017/SO12_RUN/DIAGNOSTICS/'

# %%
cd parcels_examples
# Out:
# /home/ebent/parcels_examples

# %%
from parcels import FieldSet, ParticleSet, Variable, JITParticle, AdvectionRK4, plotTrajectoriesFile
import numpy as np
import math
from datetime import timedelta
from operator import attrgetter

# %%
fieldset = FieldSet.from_parcels("MovingEddies_data/moving_eddies")

# %%
fieldset.U.show()

# %%
pset = ParticleSet.from_list(fieldset=fieldset,   # the fields on which the particles are advected
                             pclass=JITParticle,  # the type of particles (JITParticle or ScipyParticle)
                             lon=[ 3.3,  3.3],    # a vector of release longitudes 
                             lat=[46.0, 47.8])    # a vector of release latitudes

# %%
print(pset)
# Out:
# P[0](lon=3.300000, lat=46.000000, depth=0.000000, time=not_yet_set)
# P[1](lon=3.300000, lat=47.799999, depth=0.000000, time=not_yet_set)

# %%
fieldset?

# %%
pset.show(field=fieldset.U)

# %%
pset.execute(AdvectionRK4,                 # the kernel (which defines how particles move)
             runtime=timedelta(days=6),    # the total length of the run
             dt=timedelta(minutes=5),      # the timestep of the kernel
             output_file=pset.ParticleFile(name="EddyParticles.nc", outputdt=timedelta(hours=1)))  # the file name and the time step of the outputs
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error',)).History will not be written to the database.
# INFO: Compiled JITParticleAdvectionRK4 ==> /tmp/parcels-787924/cdc7a96d2f59739e8e5fc215a22d84a9.so

# %%
print(pset)
pset.show(field=fieldset.U)
# Out:
# P[0](lon=2.024550, lat=46.088692, depth=0.000000, time=518400.000000)
# P[1](lon=2.017325, lat=48.305149, depth=0.000000, time=518400.000000)

# %%
plotTrajectoriesFile('EddyParticles.nc')
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda2/envs/py2_parcels/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
plotTrajectoriesFile('EddyParticles.nc', mode='movie2d_notebook')
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fname = ‘GlobCurrent_example_data/*.nc’
filenames = {'U': fname, 'V': fname}
variables = {'U': 'eastward_eulerian_current_velocity', 'V': 'northward_eulerian_current_velocity'} dimensions = {'lat': 'lat', 'lon': ‘lon', 'depth': ‘depth’, 'time': 'time'}
fset = FieldSet.from_netcdf(filenames, variables, dimensions)

# %%
fname = load_path2+'so12_i0_year2011_5day_Uvel.nc'
fname2 = load_path2+'so12_i0_year2011_5day_Vvel.nc'

filenames = {'U': fname, 'V': fname2}
variables = {'U': 'Uvel', 'V': 'Vvel'} 
dimensions = {'lat': 'lat', 'lon': 'lon', 'depth': 'depth', 'time': 'time'}
fileset = FieldSet.from_netcdf(filenames, variables, dimensions)

# %%
dir(fileset)
# Out:
# ['U',
#  'UV',
#  'V',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_constant',
#  'add_field',
#  'add_periodic_halo',
#  'advancetime',
#  'check_complete',
#  'computeTimeChunk',
#  'eval',
#  'fields',
#  'from_data',
#  'from_nemo',
#  'from_netcdf',
#  'from_parcels',
#  'gridset',
#  'write']

# %%
fname = load_path2+'so12_i0_year2011_5day_Uvel.nc'
filenames = {'U': fname, 'V': fname}
variables = {'U': 'Uvel'} 
dimensions = {'lat': 'lat', 'lon': 'lon', 'depth': 'depth', 'time': 'time'}
#fset = FieldSet.from_netcdf(filenames, variables, dimensions)

# %%
import netCDF4

# %%
f = netCDF4.Dataset(load_path2+'so12_i0_year2008_5day_Uvel.nc','r')

# %%
f.variables.keys()
# Out:
# [u'time', u'lat', u'lon', u'depth', u'Uvel']

# %%
dir(FieldSet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_constant',
#  'add_field',
#  'add_periodic_halo',
#  'advancetime',
#  'check_complete',
#  'computeTimeChunk',
#  'eval',
#  'fields',
#  'from_data',
#  'from_nemo',
#  'from_netcdf',
#  'from_parcels',
#  'write']
